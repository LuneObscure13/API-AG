# %%
import os
import spotipy
import matplotlib.pyplot as plt
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Load credentials
client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# Set artist
artist_id = '3bgsNtcf5d5h9jbQbohfBK'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
results = spotify.artist_top_tracks(artist_id, country="ES")

print("Número de tracks recibidos:", len(results["tracks"]))
print("Primera canción:", results["tracks"][0]["name"])
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[7], line 14
#      11 # Set artist
#      12 artist_id = '3bgsNtcf5d5h9jbQbohfBK'
# ---> 14 spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
#      15 results = spotify.artist_top_tracks(artist_id, country="SP")
#      17 print("Número de tracks recibidos:", len(results["tracks"]))
#
# File ~/.local/lib/python3.11/site-packages/spotipy/oauth2.py:170, in SpotifyClientCredentials.__init__(self, client_id, client_secret, proxies, requests_session, requests_timeout, cache_handler)
#     141 """
#     142 Creates a Client Credentials Flow Manager.
#     143
#    (...)    165
#     166 """
#     168 super().__init__(requests_session)
# --> 170 self.client_id = client_id
#     171 self.client_secret = client_secret
#     172 self.proxies = proxies
#
# File ~/.local/lib/python3.11/site-packages/spotipy/oauth2.py:65, in SpotifyAuthBase.client_id(self, val)
#      63 @client_id.setter
#      64 def client_id(self, val):
# ---> 65     self._client_id = _ensure_value(val, "client_id")
#
# File ~/.local/lib/python3.11/site-packages/spotipy/oauth2.py:41, in _ensure_value(value, env_key)
#      39 if _val is None:
#      40     msg = f"No {env_key}. Pass it or set a {env_val} environment variable."
# ---> 41     raise SpotifyOauthError(msg)
#      42 return _val
#
# SpotifyOauthError: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.

# %%
    # Connect to Spotify
connection = spotipy.Spotify(
        auth_manager=SpotifyClientCredentials(
            client_id=client_id,
            client_secret=client_secret
        )
    )

    # Get top tracks for artest
response = connection.artist_top_tracks(artist_id)

    if response:

        # Get the track listing


        # Get the name, popularity and duration for each track


        # Plot the duration vs popularity


        # Save the plot
plt.savefig('./assets/duration_plot.jpg', dpi=300)
# Out:
#   Cell In[10], line 12
#     if response:
#     ^
# IndentationError: unexpected indent
